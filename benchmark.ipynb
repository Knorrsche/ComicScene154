# %%
import logging
from typing import List, Dict
import json
import pandas as pd
from collections import Counter
import random

logging.basicConfig(level=logging.WARNING, format="%(levelname)s: %(message)s")

def pk_score(predicted: List[int], reference: List[int], k: int) -> float:
    
    def binary_to_incremental(binary: List[int]) -> List[int]:
        segmentation = []
        current_segment = 0
        for marker in binary:
            segmentation.append(current_segment)
            if marker == 1:
                current_segment += 1
        return segmentation

    predicted_seg = binary_to_incremental(predicted)
    reference_seg = binary_to_incremental(reference)
    print(len(reference_seg))

    N = len(predicted_seg)
    if N != len(reference_seg):
        raise ValueError("The predicted and reference segmentations must have the same length.")
    if k <= 0 or k >= N:
        raise ValueError("Window size k must be greater than 0 and less than the sequence length.")

    mismatches = sum(
        (predicted_seg[i] == predicted_seg[i + k]) != (reference_seg[i] == reference_seg[i + k])
        for i in range(N - k)
    )

    return mismatches / (N - k) if (N - k) > 0 else 0.0

def compare_annotations(data_1: Dict, data_2: Dict, use_random: bool = False) -> float:
 
    original_pages = data_1.get("comic_data", {}).get("pages", [])
    person_pages = data_2.get("comic_data", {}).get("pages", [])

    if not original_pages or not person_pages:
        raise ValueError("One or both datasets are missing 'comic_data' or 'pages'.")

    orig_annotations_all = []
    person_annotations_all = []

    for orig_page, person_page in zip(original_pages, person_pages):
        if orig_page.get("page_number") != person_page.get("page_number"):
            logging.warning(f"Mismatch in page numbers - {orig_page.get('page_number')} vs {person_page.get('page_number')}")
            continue

        orig_annotations = [ann.get("starting_tag", None) for ann in orig_page.get("annotations", [])]
        person_annotations = [ann.get("starting_tag", None) for ann in person_page.get("annotations", [])]

        orig_annotations_all.extend(orig_annotations)
        person_annotations_all.extend(person_annotations)
        


    if use_random:
        person_annotations_all = [random.choice([0, 1]) for _ in range(len(person_annotations_all))]

    if not orig_annotations_all or not person_annotations_all:
        raise ValueError("No annotations found in one or both datasets.")

    k = 3

    return pk_score(person_annotations_all, orig_annotations_all, k)

# %%
import os
names = ["Alley_Oop", "Champ", "Treasure_Comics", "Western_Love"]

all_results = []

for name in names:
    files = [rf"Data\{name}\annotated_scenes\{name}_annotated_scenes_{i}.json" for i in range(1, 11)]
    
    metadata_path = f"Data/{name}/updated_comic_metadata.json"
    if not os.path.exists(metadata_path):
        print(f"Warning: Metadata file for {name} not found.")
        continue

    with open(metadata_path, "r", encoding="utf-8") as f:
        updated_comic_data = json.load(f)

    for i, file in enumerate(files):
        if not os.path.exists(file):
            print(f"Warning: Scene file {file} not found.")
            continue

        with open(file, "r", encoding="utf-8") as f:
            scene_data = json.load(f)

        score = compare_annotations(updated_comic_data, scene_data)

        all_results.append({
            'comic_name': name,
            'scene': f"{name}_annotated_scenes_{i + 1}.json",
            'compared_to': "updated_comic_metadata.json",
            'pk_score': score,
        })

pk_scores_df = pd.DataFrame(all_results)
pk_scores_df
# Out:
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
#          comic_name                                     scene  \
# 0         Alley_Oop         Alley_Oop_annotated_scenes_1.json
# 1         Alley_Oop         Alley_Oop_annotated_scenes_2.json
# 2         Alley_Oop         Alley_Oop_annotated_scenes_3.json
# 3         Alley_Oop         Alley_Oop_annotated_scenes_4.json
# 4         Alley_Oop         Alley_Oop_annotated_scenes_5.json
# 5         Alley_Oop         Alley_Oop_annotated_scenes_6.json
# 6         Alley_Oop         Alley_Oop_annotated_scenes_7.json
# 7         Alley_Oop         Alley_Oop_annotated_scenes_8.json
# 8         Alley_Oop         Alley_Oop_annotated_scenes_9.json
# 9         Alley_Oop        Alley_Oop_annotated_scenes_10.json
# 10            Champ             Champ_annotated_scenes_1.json
# 11            Champ             Champ_annotated_scenes_2.json
# 12            Champ             Champ_annotated_scenes_3.json
# 13            Champ             Champ_annotated_scenes_4.json
# 14            Champ             Champ_annotated_scenes_5.json
# 15            Champ             Champ_annotated_scenes_6.json
# 16            Champ             Champ_annotated_scenes_7.json
# 17            Champ             Champ_annotated_scenes_8.json
# 18            Champ             Champ_annotated_scenes_9.json
# 19            Champ            Champ_annotated_scenes_10.json
# 20  Treasure_Comics   Treasure_Comics_annotated_scenes_1.json
# 21  Treasure_Comics   Treasure_Comics_annotated_scenes_2.json
# 22  Treasure_Comics   Treasure_Comics_annotated_scenes_3.json
# 23  Treasure_Comics   Treasure_Comics_annotated_scenes_4.json
# 24  Treasure_Comics   Treasure_Comics_annotated_scenes_5.json
# 25  Treasure_Comics   Treasure_Comics_annotated_scenes_6.json
# 26  Treasure_Comics   Treasure_Comics_annotated_scenes_7.json
# 27  Treasure_Comics   Treasure_Comics_annotated_scenes_8.json
# 28  Treasure_Comics   Treasure_Comics_annotated_scenes_9.json
# 29  Treasure_Comics  Treasure_Comics_annotated_scenes_10.json
# 30     Western_Love      Western_Love_annotated_scenes_1.json
# 31     Western_Love      Western_Love_annotated_scenes_2.json
# 32     Western_Love      Western_Love_annotated_scenes_3.json
# 33     Western_Love      Western_Love_annotated_scenes_4.json
# 34     Western_Love      Western_Love_annotated_scenes_5.json
# 35     Western_Love      Western_Love_annotated_scenes_6.json
# 36     Western_Love      Western_Love_annotated_scenes_7.json
# 37     Western_Love      Western_Love_annotated_scenes_8.json
# 38     Western_Love      Western_Love_annotated_scenes_9.json
# 39     Western_Love     Western_Love_annotated_scenes_10.json
#
#                     compared_to  pk_score
# 0   updated_comic_metadata.json  0.441489
# 1   updated_comic_metadata.json  0.441489
# 2   updated_comic_metadata.json  0.425532
# 3   updated_comic_metadata.json  0.388298
# 4   updated_comic_metadata.json  0.430851
# 5   updated_comic_metadata.json  0.473404
# 6   updated_comic_metadata.json  0.446809
# 7   updated_comic_metadata.json  0.377660
# 8   updated_comic_metadata.json  0.462766
# 9   updated_comic_metadata.json  0.457447
# 10  updated_comic_metadata.json  0.392308
# 11  updated_comic_metadata.json  0.388462
# 12  updated_comic_metadata.json  0.376923
# 13  updated_comic_metadata.json  0.400000
# 14  updated_comic_metadata.json  0.426923
# 15  updated_comic_metadata.json  0.403846
# 16  updated_comic_metadata.json  0.434615
# 17  updated_comic_metadata.json  0.415385
# 18  updated_comic_metadata.json  0.384615
# 19  updated_comic_metadata.json  0.419231
# 20  updated_comic_metadata.json  0.440367
# 21  updated_comic_metadata.json  0.449541
# 22  updated_comic_metadata.json  0.435780
# 23  updated_comic_metadata.json  0.431193
# 24  updated_comic_metadata.json  0.426606
# 25  updated_comic_metadata.json  0.422018
# 26  updated_comic_metadata.json  0.444954
# 27  updated_comic_metadata.json  0.403670
# 28  updated_comic_metadata.json  0.431193
# 29  updated_comic_metadata.json  0.454128
# 30  updated_comic_metadata.json  0.445652
# 31  updated_comic_metadata.json  0.445652
# 32  updated_comic_metadata.json  0.445652
# 33  updated_comic_metadata.json  0.438406
# 34  updated_comic_metadata.json  0.434783
# 35  updated_comic_metadata.json  0.420290
# 36  updated_comic_metadata.json  0.427536
# 37  updated_comic_metadata.json  0.434783
# 38  updated_comic_metadata.json  0.394928
# 39  updated_comic_metadata.json  0.427536

# %%
comic_stats_first = pk_scores_df.groupby("comic_name")["pk_score"].describe()
comic_stats_first
# Out:
#                  count      mean       std       min       25%       50%  \
# comic_name
# Alley_Oop         10.0  0.434574  0.030817  0.377660  0.426862  0.441489
# Champ             10.0  0.404231  0.019226  0.376923  0.389423  0.401923
# Treasure_Comics   10.0  0.433945  0.014698  0.403670  0.427752  0.433486
# Western_Love      10.0  0.431522  0.015509  0.394928  0.427536  0.434783
#
#                       75%       max
# comic_name
# Alley_Oop        0.454787  0.473404
# Champ            0.418269  0.434615
# Treasure_Comics  0.443807  0.454128
# Western_Love     0.443841  0.445652

# %%
import os
names = ["Alley_Oop", "Champ", "Treasure_Comics", "Western_Love"]

all_results = []

for name in names:
    files = [rf"Data\{name}\annotated_scenes\{name}_annotated_scenes_{i}.json" for i in range(1, 11)]
    
    metadata_path = f"Data/{name}/updated_comic_metadata.json"
    if not os.path.exists(metadata_path):
        print(f"Warning: Metadata file for {name} not found.")
        continue

    with open(metadata_path, "r", encoding="utf-8") as f:
        updated_comic_data = json.load(f)

    for i, file in enumerate(files):
        if not os.path.exists(file):
            print(f"Warning: Scene file {file} not found.")
            continue

        with open(file, "r", encoding="utf-8") as f:
            scene_data = json.load(f)

        score = compare_annotations(updated_comic_data, scene_data,True)

        all_results.append({
            'comic_name': name,
            'scene': f"{name}_random_{i + 1}.json",
            'compared_to': "updated_comic_metadata.json",
            'pk_score': score,
        })

pk_scores_df = pd.DataFrame(all_results)
pk_scores_df
# Out:
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
#          comic_name                           scene  \
# 0         Alley_Oop         Alley_Oop_random_1.json
# 1         Alley_Oop         Alley_Oop_random_2.json
# 2         Alley_Oop         Alley_Oop_random_3.json
# 3         Alley_Oop         Alley_Oop_random_4.json
# 4         Alley_Oop         Alley_Oop_random_5.json
# 5         Alley_Oop         Alley_Oop_random_6.json
# 6         Alley_Oop         Alley_Oop_random_7.json
# 7         Alley_Oop         Alley_Oop_random_8.json
# 8         Alley_Oop         Alley_Oop_random_9.json
# 9         Alley_Oop        Alley_Oop_random_10.json
# 10            Champ             Champ_random_1.json
# 11            Champ             Champ_random_2.json
# 12            Champ             Champ_random_3.json
# 13            Champ             Champ_random_4.json
# 14            Champ             Champ_random_5.json
# 15            Champ             Champ_random_6.json
# 16            Champ             Champ_random_7.json
# 17            Champ             Champ_random_8.json
# 18            Champ             Champ_random_9.json
# 19            Champ            Champ_random_10.json
# 20  Treasure_Comics   Treasure_Comics_random_1.json
# 21  Treasure_Comics   Treasure_Comics_random_2.json
# 22  Treasure_Comics   Treasure_Comics_random_3.json
# 23  Treasure_Comics   Treasure_Comics_random_4.json
# 24  Treasure_Comics   Treasure_Comics_random_5.json
# 25  Treasure_Comics   Treasure_Comics_random_6.json
# 26  Treasure_Comics   Treasure_Comics_random_7.json
# 27  Treasure_Comics   Treasure_Comics_random_8.json
# 28  Treasure_Comics   Treasure_Comics_random_9.json
# 29  Treasure_Comics  Treasure_Comics_random_10.json
# 30     Western_Love      Western_Love_random_1.json
# 31     Western_Love      Western_Love_random_2.json
# 32     Western_Love      Western_Love_random_3.json
# 33     Western_Love      Western_Love_random_4.json
# 34     Western_Love      Western_Love_random_5.json
# 35     Western_Love      Western_Love_random_6.json
# 36     Western_Love      Western_Love_random_7.json
# 37     Western_Love      Western_Love_random_8.json
# 38     Western_Love      Western_Love_random_9.json
# 39     Western_Love     Western_Love_random_10.json
#
#                     compared_to  pk_score
# 0   updated_comic_metadata.json  0.494681
# 1   updated_comic_metadata.json  0.457447
# 2   updated_comic_metadata.json  0.468085
# 3   updated_comic_metadata.json  0.430851
# 4   updated_comic_metadata.json  0.409574
# 5   updated_comic_metadata.json  0.457447
# 6   updated_comic_metadata.json  0.494681
# 7   updated_comic_metadata.json  0.484043
# 8   updated_comic_metadata.json  0.489362
# 9   updated_comic_metadata.json  0.430851
# 10  updated_comic_metadata.json  0.400000
# 11  updated_comic_metadata.json  0.453846
# 12  updated_comic_metadata.json  0.453846
# 13  updated_comic_metadata.json  0.488462
# 14  updated_comic_metadata.json  0.415385
# 15  updated_comic_metadata.json  0.488462
# 16  updated_comic_metadata.json  0.465385
# 17  updated_comic_metadata.json  0.403846
# 18  updated_comic_metadata.json  0.419231
# 19  updated_comic_metadata.json  0.465385
# 20  updated_comic_metadata.json  0.449541
# 21  updated_comic_metadata.json  0.481651
# 22  updated_comic_metadata.json  0.417431
# 23  updated_comic_metadata.json  0.472477
# 24  updated_comic_metadata.json  0.467890
# 25  updated_comic_metadata.json  0.426606
# 26  updated_comic_metadata.json  0.472477
# 27  updated_comic_metadata.json  0.454128
# 28  updated_comic_metadata.json  0.509174
# 29  updated_comic_metadata.json  0.477064
# 30  updated_comic_metadata.json  0.489130
# 31  updated_comic_metadata.json  0.438406
# 32  updated_comic_metadata.json  0.507246
# 33  updated_comic_metadata.json  0.478261
# 34  updated_comic_metadata.json  0.460145
# 35  updated_comic_metadata.json  0.438406
# 36  updated_comic_metadata.json  0.434783
# 37  updated_comic_metadata.json  0.456522
# 38  updated_comic_metadata.json  0.463768
# 39  updated_comic_metadata.json  0.471014

# %%
comic_stats_random = pk_scores_df.groupby("comic_name")["pk_score"].describe()
comic_stats_random
# Out:
#                  count      mean       std       min       25%       50%  \
# comic_name
# Alley_Oop         10.0  0.461702  0.030069  0.409574  0.437500  0.462766
# Champ             10.0  0.445385  0.033373  0.400000  0.416346  0.453846
# Treasure_Comics   10.0  0.462844  0.026961  0.417431  0.450688  0.470183
# Western_Love      10.0  0.463768  0.023543  0.434783  0.442935  0.461957
#
#                       75%       max
# comic_name
# Alley_Oop        0.488032  0.494681
# Champ            0.465385  0.488462
# Treasure_Comics  0.475917  0.509174
# Western_Love     0.476449  0.507246

# %%
import pandas as pd
import json
import os
from itertools import combinations

names = ["Alley_Oop", "Champ", "Treasure_Comics", "Western_Love"]

all_results = []

for name in names:
    files = [rf"Data\{name}\annotated_scenes\{name}_annotated_scenes_{i}.json" for i in range(1, 11)]

    data = []
    for file in files:
        if not os.path.exists(file):
            print(f"Warning: Scene file {file} not found.")
            continue
        
        with open(file, "r", encoding="utf-8") as f:
            data.append(json.load(f))

    for (i, scene1), (j, scene2) in combinations(enumerate(data, 1), 2):
        score = compare_annotations(scene1, scene2)

        all_results.append({
            'comic_name': name,
            'scene_1': f"{name}_annotated_scenes_{i}.json",
            'scene_2': f"{name}_annotated_scenes_{j}.json",
            'pk_score': score,
        })

pk_scores_df = pd.DataFrame(all_results)
pk_scores_df
# Out:
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
#        comic_name                               scene_1  \
# 0       Alley_Oop     Alley_Oop_annotated_scenes_1.json
# 1       Alley_Oop     Alley_Oop_annotated_scenes_1.json
# 2       Alley_Oop     Alley_Oop_annotated_scenes_1.json
# 3       Alley_Oop     Alley_Oop_annotated_scenes_1.json
# 4       Alley_Oop     Alley_Oop_annotated_scenes_1.json
# ..            ...                                   ...
# 175  Western_Love  Western_Love_annotated_scenes_7.json
# 176  Western_Love  Western_Love_annotated_scenes_7.json
# 177  Western_Love  Western_Love_annotated_scenes_8.json
# 178  Western_Love  Western_Love_annotated_scenes_8.json
# 179  Western_Love  Western_Love_annotated_scenes_9.json
#
#                                    scene_2  pk_score
# 0        Alley_Oop_annotated_scenes_2.json  0.095745
# 1        Alley_Oop_annotated_scenes_3.json  0.111702
# 2        Alley_Oop_annotated_scenes_4.json  0.159574
# 3        Alley_Oop_annotated_scenes_5.json  0.117021
# 4        Alley_Oop_annotated_scenes_6.json  0.095745
# ..                                     ...       ...
# 175   Western_Love_annotated_scenes_9.json  0.097826
# 176  Western_Love_annotated_scenes_10.json  0.086957
# 177   Western_Love_annotated_scenes_9.json  0.090580
# 178  Western_Love_annotated_scenes_10.json  0.057971
# 179  Western_Love_annotated_scenes_10.json  0.097826
#
# [180 rows x 4 columns]

# %%
comic_stats = pk_scores_df.groupby("comic_name")["pk_score"].describe()
comic_stats
# Out:
#                  count      mean       std       min       25%       50%  \
# comic_name
# Alley_Oop         45.0  0.100118  0.031860  0.031915  0.079787  0.095745
# Champ             45.0  0.085726  0.021921  0.046154  0.073077  0.084615
# Treasure_Comics   45.0  0.045668  0.016069  0.018349  0.032110  0.045872
# Western_Love      45.0  0.071739  0.017574  0.036232  0.061594  0.076087
#
#                       75%       max
# comic_name
# Alley_Oop        0.117021  0.159574
# Champ            0.100000  0.134615
# Treasure_Comics  0.055046  0.091743
# Western_Love     0.083333  0.108696

# %%
import os
import json
import pandas as pd

names = ["Alley_Oop", "Champ", "Treasure_Comics", "Western_Love"]

all_results = []

for name in names:
    metadata_path = f"Data/{name}/updated_comic_metadata.json"
    
    if not os.path.exists(metadata_path):
        print(f"Warning: Metadata file for {name} not found.")
        continue

    with open(metadata_path, "r", encoding="utf-8") as f:
        updated_comic_data = json.load(f)

    for iter in range(1, 11):
        for i in range(1, 11):
            file_path = rf"Data\{name}\refined_scenes\{iter}\{name}_{iter}_refined_scenes_{i}.json"

            if not os.path.exists(file_path):
                print(f"Warning: Scene file {file_path} not found.")
                continue

            with open(file_path, "r", encoding="utf-8") as f:
                scene_data = json.load(f)

            score = compare_annotations(updated_comic_data, scene_data)

            all_results.append({
                'comic_name': name,
                'iteration': iter,
                'scene': f"{name}_{iter}_refined_scenes_{i}.json",
                'compared_to': "updated_comic_metadata.json",
                'pk_score': score,
            })

pk_scores_df = pd.DataFrame(all_results)

pk_scores_df
# Out:
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# Warning: Scene file Data\Alley_Oop\refined_scenes\2\Alley_Oop_2_refined_scenes_2.json not found.
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# Warning: Scene file Data\Alley_Oop\refined_scenes\4\Alley_Oop_4_refined_scenes_5.json not found.
# 191
# Warning: Scene file Data\Alley_Oop\refined_scenes\4\Alley_Oop_4_refined_scenes_7.json not found.
# 191
# 191
# Warning: Scene file Data\Alley_Oop\refined_scenes\4\Alley_Oop_4_refined_scenes_10.json not found.
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# Warning: Scene file Data\Alley_Oop\refined_scenes\6\Alley_Oop_6_refined_scenes_2.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\6\Alley_Oop_6_refined_scenes_3.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\6\Alley_Oop_6_refined_scenes_4.json not found.
# 191
# 191
# 191
# Warning: Scene file Data\Alley_Oop\refined_scenes\6\Alley_Oop_6_refined_scenes_8.json not found.
# 191
# 191
# 191
# Warning: Scene file Data\Alley_Oop\refined_scenes\7\Alley_Oop_7_refined_scenes_2.json not found.
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# Warning: Scene file Data\Alley_Oop\refined_scenes\8\Alley_Oop_8_refined_scenes_1.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\8\Alley_Oop_8_refined_scenes_2.json not found.
# 191
# Warning: Scene file Data\Alley_Oop\refined_scenes\8\Alley_Oop_8_refined_scenes_4.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\8\Alley_Oop_8_refined_scenes_5.json not found.
# 191
# 191
# 191
# 191
# Warning: Scene file Data\Alley_Oop\refined_scenes\8\Alley_Oop_8_refined_scenes_10.json not found.
# 191
# 191
# 191
# 191
# Warning: Scene file Data\Alley_Oop\refined_scenes\9\Alley_Oop_9_refined_scenes_5.json not found.
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# Warning: Scene file Data\Alley_Oop\refined_scenes\10\Alley_Oop_10_refined_scenes_8.json not found.
# 191
# Warning: Scene file Data\Alley_Oop\refined_scenes\10\Alley_Oop_10_refined_scenes_10.json not found.
# Warning: Scene file Data\Champ\refined_scenes\1\Champ_1_refined_scenes_1.json not found.
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# Warning: Scene file Data\Champ\refined_scenes\1\Champ_1_refined_scenes_10.json not found.
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# Warning: Scene file Data\Champ\refined_scenes\5\Champ_5_refined_scenes_2.json not found.
# 263
# 263
# 263
# 263
# Warning: Scene file Data\Champ\refined_scenes\5\Champ_5_refined_scenes_7.json not found.
# 263
# 263
# 263
# 263
# 263
# 263
# Warning: Scene file Data\Champ\refined_scenes\6\Champ_6_refined_scenes_4.json not found.
# 263
# 263
# 263
# 263
# 263
# 263
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_1.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_2.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_3.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_4.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_5.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_6.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_7.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_8.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_9.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_10.json not found.
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# Warning: Scene file Data\Champ\refined_scenes\10\Champ_10_refined_scenes_9.json not found.
# 263
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# Warning: Scene file Data\Treasure_Comics\refined_scenes\3\Treasure_Comics_3_refined_scenes_6.json not found.
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# Warning: Scene file Data\Treasure_Comics\refined_scenes\4\Treasure_Comics_4_refined_scenes_9.json not found.
# 221
# 221
# 221
# Warning: Scene file Data\Treasure_Comics\refined_scenes\5\Treasure_Comics_5_refined_scenes_3.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\5\Treasure_Comics_5_refined_scenes_4.json not found.
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# Warning: Scene file Data\Treasure_Comics\refined_scenes\10\Treasure_Comics_10_refined_scenes_7.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\10\Treasure_Comics_10_refined_scenes_8.json not found.
# 221
# Warning: Scene file Data\Treasure_Comics\refined_scenes\10\Treasure_Comics_10_refined_scenes_10.json not found.
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# Warning: Scene file Data\Western_Love\refined_scenes\3\Western_Love_3_refined_scenes_6.json not found.
# Warning: Scene file Data\Western_Love\refined_scenes\3\Western_Love_3_refined_scenes_7.json not found.
# 279
# Warning: Scene file Data\Western_Love\refined_scenes\3\Western_Love_3_refined_scenes_9.json not found.
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# Warning: Scene file Data\Western_Love\refined_scenes\5\Western_Love_5_refined_scenes_4.json not found.
# Warning: Scene file Data\Western_Love\refined_scenes\5\Western_Love_5_refined_scenes_5.json not found.
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# Warning: Scene file Data\Western_Love\refined_scenes\7\Western_Love_7_refined_scenes_7.json not found.
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
#        comic_name  iteration                                   scene  \
# 0       Alley_Oop          1       Alley_Oop_1_refined_scenes_1.json
# 1       Alley_Oop          1       Alley_Oop_1_refined_scenes_2.json
# 2       Alley_Oop          1       Alley_Oop_1_refined_scenes_3.json
# 3       Alley_Oop          1       Alley_Oop_1_refined_scenes_4.json
# 4       Alley_Oop          1       Alley_Oop_1_refined_scenes_5.json
# ..            ...        ...                                     ...
# 349  Western_Love         10   Western_Love_10_refined_scenes_6.json
# 350  Western_Love         10   Western_Love_10_refined_scenes_7.json
# 351  Western_Love         10   Western_Love_10_refined_scenes_8.json
# 352  Western_Love         10   Western_Love_10_refined_scenes_9.json
# 353  Western_Love         10  Western_Love_10_refined_scenes_10.json
#
#                      compared_to  pk_score
# 0    updated_comic_metadata.json  0.388298
# 1    updated_comic_metadata.json  0.260638
# 2    updated_comic_metadata.json  0.265957
# 3    updated_comic_metadata.json  0.265957
# 4    updated_comic_metadata.json  0.239362
# ..                           ...       ...
# 349  updated_comic_metadata.json  0.442029
# 350  updated_comic_metadata.json  0.442029
# 351  updated_comic_metadata.json  0.442029
# 352  updated_comic_metadata.json  0.442029
# 353  updated_comic_metadata.json  0.442029
#
# [354 rows x 5 columns]

# %%
comic_stats = pk_scores_df.groupby(["comic_name", "iteration"])["pk_score"].describe()
comic_stats = comic_stats.sort_index(level=["comic_name", "iteration"])
comic_stats
# Out:
#                            count      mean           std       min       25%  \
# comic_name      iteration
# Alley_Oop       1           10.0  0.273404  4.114087e-02  0.239362  0.260638
#                 2            9.0  0.285461  7.036573e-03  0.271277  0.281915
#                 3           10.0  0.289894  3.761206e-03  0.287234  0.287234
#                 4            7.0  0.344985  1.853543e-02  0.303191  0.351064
#                 5           10.0  0.354787  4.379110e-03  0.351064  0.351064
#                 6            6.0  0.366135  5.229745e-03  0.356383  0.367021
#                 7            9.0  0.412530  4.765844e-02  0.372340  0.372340
#                 8            5.0  0.452128  6.206335e-17  0.452128  0.452128
#                 9            9.0  0.456265  2.345524e-03  0.452128  0.457447
#                 10           8.0  0.458112  1.880603e-03  0.457447  0.457447
# Champ           1            8.0  0.416827  7.186495e-02  0.350000  0.357692
#                 2           10.0  0.370769  6.587299e-03  0.357692  0.370192
#                 3           10.0  0.385385  5.063697e-03  0.380769  0.380769
#                 4           10.0  0.393846  7.734925e-03  0.384615  0.388462
#                 5            8.0  0.406250  2.861630e-03  0.403846  0.403846
#                 6            9.0  0.408547  1.695994e-03  0.407692  0.407692
#                 8           10.0  0.407692  0.000000e+00  0.407692  0.407692
#                 9           10.0  0.410000  3.715738e-03  0.407692  0.407692
#                 10           9.0  0.415385  0.000000e+00  0.415385  0.415385
# Treasure_Comics 1           10.0  0.347248  1.467412e-02  0.330275  0.339450
#                 2           10.0  0.344954  6.414733e-03  0.334862  0.344037
#                 3            9.0  0.375637  4.549411e-02  0.330275  0.348624
#                 4            9.0  0.435780  0.000000e+00  0.435780  0.435780
#                 5            8.0  0.435780  0.000000e+00  0.435780  0.435780
#                 6           10.0  0.435780  0.000000e+00  0.435780  0.435780
#                 7           10.0  0.439908  6.647421e-03  0.435780  0.435780
#                 8           10.0  0.449541  0.000000e+00  0.449541  0.449541
#                 9           10.0  0.449541  0.000000e+00  0.449541  0.449541
#                 10           7.0  0.449541  5.995890e-17  0.449541  0.449541
# Western_Love    1           10.0  0.385145  8.200118e-03  0.365942  0.384058
#                 2           10.0  0.369928  9.729533e-03  0.362319  0.362319
#                 3            7.0  0.365942  2.958321e-03  0.362319  0.364130
#                 4           10.0  0.374638  4.252854e-03  0.365942  0.373188
#                 5            8.0  0.389493  1.060761e-02  0.376812  0.376812
#                 6           10.0  0.397464  1.750166e-03  0.394928  0.395833
#                 7            9.0  0.393317  3.673166e-03  0.391304  0.391304
#                 8           10.0  0.403623  3.055341e-03  0.402174  0.402174
#                 9           10.0  0.421739  1.268978e-02  0.405797  0.409420
#                 10          10.0  0.438406  3.819176e-03  0.434783  0.434783
#
#                                 50%       75%       max
# comic_name      iteration
# Alley_Oop       1          0.263298  0.265957  0.388298
#                 2          0.287234  0.292553  0.292553
#                 3          0.287234  0.292553  0.297872
#                 4          0.351064  0.351064  0.356383
#                 5          0.353723  0.356383  0.361702
#                 6          0.367021  0.367021  0.372340
#                 7          0.372340  0.462766  0.462766
#                 8          0.452128  0.452128  0.452128
#                 9          0.457447  0.457447  0.457447
#                 10         0.457447  0.457447  0.462766
# Champ           1          0.398077  0.456731  0.523077
#                 2          0.373077  0.373077  0.380769
#                 3          0.384615  0.390385  0.392308
#                 4          0.392308  0.401923  0.403846
#                 5          0.405769  0.407692  0.411538
#                 6          0.407692  0.407692  0.411538
#                 8          0.407692  0.407692  0.407692
#                 9          0.407692  0.413462  0.415385
#                 10         0.415385  0.415385  0.415385
# Treasure_Comics 1          0.346330  0.348624  0.385321
#                 2          0.344037  0.348624  0.353211
#                 3          0.348624  0.435780  0.435780
#                 4          0.435780  0.435780  0.435780
#                 5          0.435780  0.435780  0.435780
#                 6          0.435780  0.435780  0.435780
#                 7          0.435780  0.446101  0.449541
#                 8          0.449541  0.449541  0.449541
#                 9          0.449541  0.449541  0.449541
#                 10         0.449541  0.449541  0.449541
# Western_Love    1          0.385870  0.387681  0.394928
#                 2          0.365942  0.375000  0.387681
#                 3          0.365942  0.367754  0.369565
#                 4          0.376812  0.376812  0.380435
#                 5          0.394928  0.398551  0.398551
#                 6          0.398551  0.398551  0.398551
#                 7          0.391304  0.394928  0.402174
#                 8          0.402174  0.402174  0.409420
#                 9          0.420290  0.434783  0.434783
#                 10         0.438406  0.442029  0.442029

# %%
comic_mean = pk_scores_df.groupby("comic_name")["pk_score"].mean()
comic_mean
# Out:
# comic_name
# Alley_Oop          0.362728
# Champ              0.400916
# Treasure_Comics    0.415113
# Western_Love       0.394966
# Name: pk_score, dtype: float64

# %%
comic_stats_first
# Out:
#                  count      mean       std       min       25%       50%  \
# comic_name
# Alley_Oop         10.0  0.434574  0.030817  0.377660  0.426862  0.441489
# Champ             10.0  0.404231  0.019226  0.376923  0.389423  0.401923
# Treasure_Comics   10.0  0.433945  0.014698  0.403670  0.427752  0.433486
# Western_Love      10.0  0.431522  0.015509  0.394928  0.427536  0.434783
#
#                       75%       max
# comic_name
# Alley_Oop        0.454787  0.473404
# Champ            0.418269  0.434615
# Treasure_Comics  0.443807  0.454128
# Western_Love     0.443841  0.445652

# %%
comic_stats_random
# Out:
#                  count      mean       std       min       25%       50%  \
# comic_name
# Alley_Oop         10.0  0.461702  0.030069  0.409574  0.437500  0.462766
# Champ             10.0  0.445385  0.033373  0.400000  0.416346  0.453846
# Treasure_Comics   10.0  0.462844  0.026961  0.417431  0.450688  0.470183
# Western_Love      10.0  0.463768  0.023543  0.434783  0.442935  0.461957
#
#                       75%       max
# comic_name
# Alley_Oop        0.488032  0.494681
# Champ            0.465385  0.488462
# Treasure_Comics  0.475917  0.509174
# Western_Love     0.476449  0.507246

# %%
import pandas as pd
import json
import os
from itertools import combinations

names = ["Alley_Oop", "Champ", "Treasure_Comics", "Western_Love"]

all_results = []

scene_data = {}

for name in names:
    scene_data[name] = {}

    for iter in range(1, 11):
        scene_data[name][iter] = []

        for i in range(1, 11):
            file_path = rf"Data\{name}\refined_scenes\{iter}\{name}_{iter}_refined_scenes_{i}.json"

            if not os.path.exists(file_path):
                print(f"Warning: Scene file {file_path} not found.")
                continue

            with open(file_path, "r", encoding="utf-8") as f:
                scene_data[name][iter].append(json.load(f))

for name in names:
    for iter in range(1, 11):
        scenes = scene_data[name].get(iter, [])

        for (i, scene1), (j, scene2) in combinations(enumerate(scenes, 1), 2):
            score = compare_annotations(scene1, scene2)

            all_results.append({
                'comic_name': name,
                'iteration': iter,
                'scene_1': f"{name}_{iter}_refined_scenes_{i}.json",
                'scene_2': f"{name}_{iter}_refined_scenes_{j}.json",
                'pk_score': score,
            })

pk_scores_df = pd.DataFrame(all_results)

pk_scores_df
# Out:
# Warning: Scene file Data\Alley_Oop\refined_scenes\2\Alley_Oop_2_refined_scenes_2.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\4\Alley_Oop_4_refined_scenes_5.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\4\Alley_Oop_4_refined_scenes_7.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\4\Alley_Oop_4_refined_scenes_10.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\6\Alley_Oop_6_refined_scenes_2.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\6\Alley_Oop_6_refined_scenes_3.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\6\Alley_Oop_6_refined_scenes_4.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\6\Alley_Oop_6_refined_scenes_8.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\7\Alley_Oop_7_refined_scenes_2.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\8\Alley_Oop_8_refined_scenes_1.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\8\Alley_Oop_8_refined_scenes_2.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\8\Alley_Oop_8_refined_scenes_4.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\8\Alley_Oop_8_refined_scenes_5.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\8\Alley_Oop_8_refined_scenes_10.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\9\Alley_Oop_9_refined_scenes_5.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\10\Alley_Oop_10_refined_scenes_8.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\10\Alley_Oop_10_refined_scenes_10.json not found.
# Warning: Scene file Data\Champ\refined_scenes\1\Champ_1_refined_scenes_1.json not found.
# Warning: Scene file Data\Champ\refined_scenes\1\Champ_1_refined_scenes_10.json not found.
# Warning: Scene file Data\Champ\refined_scenes\5\Champ_5_refined_scenes_2.json not found.
# Warning: Scene file Data\Champ\refined_scenes\5\Champ_5_refined_scenes_7.json not found.
# Warning: Scene file Data\Champ\refined_scenes\6\Champ_6_refined_scenes_4.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_1.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_2.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_3.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_4.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_5.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_6.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_7.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_8.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_9.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_10.json not found.
# Warning: Scene file Data\Champ\refined_scenes\10\Champ_10_refined_scenes_9.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\3\Treasure_Comics_3_refined_scenes_6.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\4\Treasure_Comics_4_refined_scenes_9.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\5\Treasure_Comics_5_refined_scenes_3.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\5\Treasure_Comics_5_refined_scenes_4.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\10\Treasure_Comics_10_refined_scenes_7.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\10\Treasure_Comics_10_refined_scenes_8.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\10\Treasure_Comics_10_refined_scenes_10.json not found.
# Warning: Scene file Data\Western_Love\refined_scenes\3\Western_Love_3_refined_scenes_6.json not found.
# Warning: Scene file Data\Western_Love\refined_scenes\3\Western_Love_3_refined_scenes_7.json not found.
# Warning: Scene file Data\Western_Love\refined_scenes\3\Western_Love_3_refined_scenes_9.json not found.
# Warning: Scene file Data\Western_Love\refined_scenes\5\Western_Love_5_refined_scenes_4.json not found.
# Warning: Scene file Data\Western_Love\refined_scenes\5\Western_Love_5_refined_scenes_5.json not found.
# Warning: Scene file Data\Western_Love\refined_scenes\7\Western_Love_7_refined_scenes_7.json not found.
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
#         comic_name  iteration                                scene_1  \
# 0        Alley_Oop          1      Alley_Oop_1_refined_scenes_1.json
# 1        Alley_Oop          1      Alley_Oop_1_refined_scenes_1.json
# 2        Alley_Oop          1      Alley_Oop_1_refined_scenes_1.json
# 3        Alley_Oop          1      Alley_Oop_1_refined_scenes_1.json
# 4        Alley_Oop          1      Alley_Oop_1_refined_scenes_1.json
# ...            ...        ...                                    ...
# 1456  Western_Love         10  Western_Love_10_refined_scenes_7.json
# 1457  Western_Love         10  Western_Love_10_refined_scenes_7.json
# 1458  Western_Love         10  Western_Love_10_refined_scenes_8.json
# 1459  Western_Love         10  Western_Love_10_refined_scenes_8.json
# 1460  Western_Love         10  Western_Love_10_refined_scenes_9.json
#
#                                      scene_2  pk_score
# 0          Alley_Oop_1_refined_scenes_2.json  0.255319
# 1          Alley_Oop_1_refined_scenes_3.json  0.281915
# 2          Alley_Oop_1_refined_scenes_4.json  0.281915
# 3          Alley_Oop_1_refined_scenes_5.json  0.319149
# 4          Alley_Oop_1_refined_scenes_6.json  0.382979
# ...                                      ...       ...
# 1456   Western_Love_10_refined_scenes_9.json  0.000000
# 1457  Western_Love_10_refined_scenes_10.json  0.000000
# 1458   Western_Love_10_refined_scenes_9.json  0.000000
# 1459  Western_Love_10_refined_scenes_10.json  0.000000
# 1460  Western_Love_10_refined_scenes_10.json  0.000000
#
# [1461 rows x 5 columns]

# %%
comic_stats = pk_scores_df.groupby(["comic_name", "iteration"])["pk_score"].describe()
comic_stats = comic_stats.sort_index(level=["comic_name", "iteration"])
comic_stats
# Out:
#                            count      mean       std  min       25%       50%  \
# comic_name      iteration
# Alley_Oop       1           45.0  0.129314  0.123251  0.0  0.031915  0.106383
#                 2           36.0  0.007979  0.006031  0.0  0.005319  0.005319
#                 3           45.0  0.006738  0.006651  0.0  0.000000  0.005319
#                 4           21.0  0.024316  0.036605  0.0  0.000000  0.005319
#                 5           45.0  0.013830  0.010041  0.0  0.005319  0.010638
#                 6           15.0  0.011702  0.007576  0.0  0.007979  0.010638
#                 7           36.0  0.056147  0.050931  0.0  0.000000  0.101064
#                 8           10.0  0.000000  0.000000  0.0  0.000000  0.000000
#                 9           36.0  0.002069  0.002630  0.0  0.000000  0.000000
#                 10          28.0  0.001330  0.002346  0.0  0.000000  0.000000
# Champ           1           28.0  0.294643  0.215960  0.0  0.068269  0.380769
#                 2           45.0  0.009915  0.011317  0.0  0.000000  0.007692
#                 3           45.0  0.011282  0.007710  0.0  0.003846  0.011538
#                 4           45.0  0.020855  0.014449  0.0  0.007692  0.019231
#                 5           28.0  0.006456  0.005544  0.0  0.002885  0.003846
#                 6           36.0  0.003205  0.004551  0.0  0.000000  0.000000
#                 8           45.0  0.000000  0.000000  0.0  0.000000  0.000000
#                 9           45.0  0.003590  0.003881  0.0  0.000000  0.000000
#                 10          36.0  0.003846  0.003901  0.0  0.000000  0.003846
# Treasure_Comics 1           45.0  0.093884  0.067584  0.0  0.036697  0.082569
#                 2           45.0  0.034862  0.027495  0.0  0.009174  0.041284
#                 3           36.0  0.148063  0.110155  0.0  0.013761  0.167431
#                 4           36.0  0.000000  0.000000  0.0  0.000000  0.000000
#                 5           28.0  0.000000  0.000000  0.0  0.000000  0.000000
#                 6           45.0  0.000000  0.000000  0.0  0.000000  0.000000
#                 7           45.0  0.006422  0.006943  0.0  0.000000  0.000000
#                 8           45.0  0.000000  0.000000  0.0  0.000000  0.000000
#                 9           45.0  0.000000  0.000000  0.0  0.000000  0.000000
#                 10          21.0  0.000000  0.000000  0.0  0.000000  0.000000
# Western_Love    1           45.0  0.048551  0.043577  0.0  0.018116  0.039855
#                 2           45.0  0.034541  0.031279  0.0  0.010870  0.028986
#                 3           21.0  0.016218  0.011996  0.0  0.003623  0.014493
#                 4           45.0  0.011755  0.008980  0.0  0.003623  0.007246
#                 5           28.0  0.069099  0.059982  0.0  0.009964  0.112319
#                 6           45.0  0.001691  0.001828  0.0  0.000000  0.000000
#                 7           36.0  0.009461  0.007051  0.0  0.006341  0.009058
#                 8           45.0  0.002576  0.003508  0.0  0.000000  0.000000
#                 9           45.0  0.018357  0.013609  0.0  0.000000  0.021739
#                 10          45.0  0.004026  0.003641  0.0  0.000000  0.007246
#
#                                 75%       max
# comic_name      iteration
# Alley_Oop       1          0.143617  0.425532
#                 2          0.010638  0.021277
#                 3          0.010638  0.021277
#                 4          0.079787  0.085106
#                 5          0.021277  0.031915
#                 6          0.015957  0.026596
#                 7          0.101064  0.101064
#                 8          0.000000  0.000000
#                 9          0.005319  0.005319
#                 10         0.001330  0.005319
# Champ           1          0.478846  0.596154
#                 2          0.011538  0.038462
#                 3          0.019231  0.026923
#                 4          0.030769  0.042308
#                 5          0.011538  0.015385
#                 6          0.003846  0.011538
#                 8          0.000000  0.000000
#                 9          0.007692  0.007692
#                 10         0.007692  0.007692
# Treasure_Comics 1          0.146789  0.238532
#                 2          0.055046  0.100917
#                 3          0.188073  0.334862
#                 4          0.000000  0.000000
#                 5          0.000000  0.000000
#                 6          0.000000  0.000000
#                 7          0.013761  0.013761
#                 8          0.000000  0.000000
#                 9          0.000000  0.000000
#                 10         0.000000  0.000000
# Western_Love    1          0.105072  0.126812
#                 2          0.050725  0.108696
#                 3          0.021739  0.039855
#                 4          0.018116  0.032609
#                 5          0.123188  0.130435
#                 6          0.003623  0.003623
#                 7          0.010870  0.028986
#                 8          0.007246  0.007246
#                 9          0.036232  0.036232
#                 10         0.007246  0.007246

# %%
import pandas as pd
import json
import os
from itertools import combinations

names = ["Alley_Oop", "Champ", "Treasure_Comics", "Western_Love"]

all_results = []

scene_data = {}

for name in names:
    scene_data[name] = {}

    for iter in range(1, 11):
        scene_data[name][iter] = []

        for i in range(1, 11):
            file_path = rf"Data\{name}\refined_scenes\{iter}\{name}_{iter}_refined_scenes_{i}.json"

            if not os.path.exists(file_path):
                print(f"Warning: Scene file {file_path} not found.")
                continue

            with open(file_path, "r", encoding="utf-8") as f:
                scene_data[name][iter].append(json.load(f))

for name in names:
    for (iter1, iter2) in combinations(range(1, 11), 2):
        scenes1 = scene_data[name].get(iter1, [])
        scenes2 = scene_data[name].get(iter2, [])

        for (i, scene1), (j, scene2) in combinations(enumerate(scenes1, 1), 2):
            score = compare_annotations(scene1, scene2)

            all_results.append({
                'comic_name': name,
                'iteration_1': iter1,
                'iteration_2': iter2,
                'scene_1': f"{name}_{iter1}_refined_scenes_{i}.json",
                'scene_2': f"{name}_{iter2}_refined_scenes_{j}.json",
                'pk_score': score,
            })

pk_scores_df = pd.DataFrame(all_results)

pk_scores_df
# Out:
# Warning: Scene file Data\Alley_Oop\refined_scenes\2\Alley_Oop_2_refined_scenes_2.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\4\Alley_Oop_4_refined_scenes_5.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\4\Alley_Oop_4_refined_scenes_7.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\4\Alley_Oop_4_refined_scenes_10.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\6\Alley_Oop_6_refined_scenes_2.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\6\Alley_Oop_6_refined_scenes_3.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\6\Alley_Oop_6_refined_scenes_4.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\6\Alley_Oop_6_refined_scenes_8.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\7\Alley_Oop_7_refined_scenes_2.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\8\Alley_Oop_8_refined_scenes_1.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\8\Alley_Oop_8_refined_scenes_2.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\8\Alley_Oop_8_refined_scenes_4.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\8\Alley_Oop_8_refined_scenes_5.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\8\Alley_Oop_8_refined_scenes_10.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\9\Alley_Oop_9_refined_scenes_5.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\10\Alley_Oop_10_refined_scenes_8.json not found.
# Warning: Scene file Data\Alley_Oop\refined_scenes\10\Alley_Oop_10_refined_scenes_10.json not found.
# Warning: Scene file Data\Champ\refined_scenes\1\Champ_1_refined_scenes_1.json not found.
# Warning: Scene file Data\Champ\refined_scenes\1\Champ_1_refined_scenes_10.json not found.
# Warning: Scene file Data\Champ\refined_scenes\5\Champ_5_refined_scenes_2.json not found.
# Warning: Scene file Data\Champ\refined_scenes\5\Champ_5_refined_scenes_7.json not found.
# Warning: Scene file Data\Champ\refined_scenes\6\Champ_6_refined_scenes_4.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_1.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_2.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_3.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_4.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_5.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_6.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_7.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_8.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_9.json not found.
# Warning: Scene file Data\Champ\refined_scenes\7\Champ_7_refined_scenes_10.json not found.
# Warning: Scene file Data\Champ\refined_scenes\10\Champ_10_refined_scenes_9.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\3\Treasure_Comics_3_refined_scenes_6.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\4\Treasure_Comics_4_refined_scenes_9.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\5\Treasure_Comics_5_refined_scenes_3.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\5\Treasure_Comics_5_refined_scenes_4.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\10\Treasure_Comics_10_refined_scenes_7.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\10\Treasure_Comics_10_refined_scenes_8.json not found.
# Warning: Scene file Data\Treasure_Comics\refined_scenes\10\Treasure_Comics_10_refined_scenes_10.json not found.
# Warning: Scene file Data\Western_Love\refined_scenes\3\Western_Love_3_refined_scenes_6.json not found.
# Warning: Scene file Data\Western_Love\refined_scenes\3\Western_Love_3_refined_scenes_7.json not found.
# Warning: Scene file Data\Western_Love\refined_scenes\3\Western_Love_3_refined_scenes_9.json not found.
# Warning: Scene file Data\Western_Love\refined_scenes\5\Western_Love_5_refined_scenes_4.json not found.
# Warning: Scene file Data\Western_Love\refined_scenes\5\Western_Love_5_refined_scenes_5.json not found.
# Warning: Scene file Data\Western_Love\refined_scenes\7\Western_Love_7_refined_scenes_7.json not found.
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 191
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 263
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
# 279
#         comic_name  iteration_1  iteration_2  \
# 0        Alley_Oop            1            2
# 1        Alley_Oop            1            2
# 2        Alley_Oop            1            2
# 3        Alley_Oop            1            2
# 4        Alley_Oop            1            2
# ...            ...          ...          ...
# 6762  Western_Love            9           10
# 6763  Western_Love            9           10
# 6764  Western_Love            9           10
# 6765  Western_Love            9           10
# 6766  Western_Love            9           10
#
#                                    scene_1  \
# 0        Alley_Oop_1_refined_scenes_1.json
# 1        Alley_Oop_1_refined_scenes_1.json
# 2        Alley_Oop_1_refined_scenes_1.json
# 3        Alley_Oop_1_refined_scenes_1.json
# 4        Alley_Oop_1_refined_scenes_1.json
# ...                                    ...
# 6762  Western_Love_9_refined_scenes_7.json
# 6763  Western_Love_9_refined_scenes_7.json
# 6764  Western_Love_9_refined_scenes_8.json
# 6765  Western_Love_9_refined_scenes_8.json
# 6766  Western_Love_9_refined_scenes_9.json
#
#                                      scene_2  pk_score
# 0          Alley_Oop_2_refined_scenes_2.json  0.255319
# 1          Alley_Oop_2_refined_scenes_3.json  0.281915
# 2          Alley_Oop_2_refined_scenes_4.json  0.281915
# 3          Alley_Oop_2_refined_scenes_5.json  0.319149
# 4          Alley_Oop_2_refined_scenes_6.json  0.382979
# ...                                      ...       ...
# 6762   Western_Love_10_refined_scenes_9.json  0.000000
# 6763  Western_Love_10_refined_scenes_10.json  0.000000
# 6764   Western_Love_10_refined_scenes_9.json  0.000000
# 6765  Western_Love_10_refined_scenes_10.json  0.000000
# 6766  Western_Love_10_refined_scenes_10.json  0.000000
#
# [6767 rows x 6 columns]

# %%
comic_stats = pk_scores_df.groupby("comic_name")["pk_score"].describe()
comic_stats = comic_stats.sort_index(level="comic_name")
comic_stats
# Out:
#                   count      mean       std  min       25%       50%  \
# comic_name
# Alley_Oop        1583.0  0.044099  0.082207  0.0  0.005319  0.010638
# Champ            1616.0  0.054784  0.133278  0.0  0.000000  0.011538
# Treasure_Comics  1823.0  0.048685  0.075080  0.0  0.000000  0.009174
# Western_Love     1745.0  0.028489  0.036917  0.0  0.003623  0.014493
#
#                       75%       max
# comic_name
# Alley_Oop        0.031915  0.425532
# Champ            0.023077  0.596154
# Treasure_Comics  0.064220  0.334862
# Western_Love     0.039855  0.130435

# %%
import logging
import json
import random
from typing import List, Dict

logging.basicConfig(level=logging.WARNING, format="%(levelname)s: %(message)s")

def pk_score(predicted: List[int], reference: List[int], k: int) -> float:
    def binary_to_incremental(binary: List[int]) -> List[int]:
        segmentation = []
        current_segment = 0
        for marker in binary:
            segmentation.append(current_segment)
            if marker == 1:
                current_segment += 1
        return segmentation

    predicted_seg = binary_to_incremental(predicted)
    reference_seg = binary_to_incremental(reference)

    N = len(predicted_seg)
    if N != len(reference_seg):
        raise ValueError("Predicted and reference segmentations must have the same length.")
    if k <= 0 or k >= N:
        raise ValueError("Window size k must be greater than 0 and less than sequence length.")

    mismatches = sum(
        (predicted_seg[i] == predicted_seg[i + k]) != (reference_seg[i] == reference_seg[i + k])
        for i in range(N - k)
    )

    return mismatches / (N - k) if (N - k) > 0 else 0.0

def flatten_pages(data: Dict) -> List[int]:
    """Extracts and flattens all page arrays into a single list."""
    flattened = []
    for chapter in data.get("comic", {}).get("chapters", []):
        for page in chapter.get("pages", []):
            flattened.extend(page)  # Append all values in page list
    return flattened

def compare_annotations(data_1: Dict, data_2: Dict, use_random: bool = False) -> float:
    original_annotations = flatten_pages(data_1)
    person_annotations = flatten_pages(data_2)

    if use_random:
        person_annotations = [random.choice([0, 1]) for _ in range(len(person_annotations))]

    if len(original_annotations) != len(person_annotations):
        raise ValueError("The datasets must have the same number of annotations for comparison.")

    k = 3  # Window size
    return pk_score(person_annotations, original_annotations, k)
names = ["Liberty", "Sain", "Arab", "Twinkle","Six","Marco"]
for name in names:
    # Example usage:
    with open(rf"C:\Users\derra\Desktop\Paper\{name}.json", "r") as f:
        data_1 = json.load(f)
    
    with open(rf"C:\Users\derra\Desktop\Paper\{name}_1.json", "r") as f:
        data_2 = json.load(f)
    
    with open(rf"C:\Users\derra\Desktop\Paper\{name}_2.json", "r") as f:
        data_3 = json.load(f)
    
    score_1 = compare_annotations(data_1, data_2)
    score_2 = compare_annotations(data_1, data_3)
    score_3 = compare_annotations(data_2,data_3)
    print(f"{name}:   P_k Score 1: {score_1:.4f}           P_k Score 2: {score_2:.4f}           P_k Score 3: {score_3:.4f}")
# Out:
# Liberty:   P_k Score 1: 0.2093           P_k Score 2: 0.0698           P_k Score 3: 0.2791
# Sain:   P_k Score 1: 0.0698           P_k Score 2: 0.0000           P_k Score 3: 0.0698
# Arab:   P_k Score 1: 0.1667           P_k Score 2: 0.3333           P_k Score 3: 0.2619
# Twinkle:   P_k Score 1: 0.2727           P_k Score 2: 0.1636           P_k Score 3: 0.2182
# Six:   P_k Score 1: 0.1224           P_k Score 2: 0.3673           P_k Score 3: 0.2857
# Marco:   P_k Score 1: 0.0556           P_k Score 2: 0.1944           P_k Score 3: 0.1389
